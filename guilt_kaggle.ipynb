# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.utils import shuffle
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('./data/train.csv')
# data = shuffle(data, random_state = 0)

status = data["Violation Status"].unique()
license_type = data["License Type"].unique()
violation = data["Violation"].unique()
county = data["County"].unique()
issu_agency = data["Issuing Agency"].unique()
state = data["State"].unique()
data.head(10)
# Out:
#          ID    Plate State License Type  Summons Number  Issue Date  \
# 0  24497127  HFP7960    NY          PAS      7070129129  01/22/2017
# 1  31015569  85027JW    NY          COM      8424520324  09/30/2016
# 2  34247801  HHS1694    NY          PAS      8533807454  09/25/2017
# 3  36714941  2028686    IN          PAS      8477607047  02/15/2017
# 4  18489070  HJP7255    NY          PAS      8253044689  09/09/2016
# 5  22817328   ATZ880    NY          PAS      7029937648  11/17/2016
# 6  29440098  59244JY    NY          COM      8058027716  09/07/2016
# 7  28132947   2ANPM3    CT          CMB      8279508971  04/25/2016
# 8   6353873   AR992C    NJ          PAS      8478186920  01/25/2018
# 9  13444911  46959JY    NY          COM      1450941722  01/12/2019
#
#   Violation Time                       Violation Judgment Entry Date  \
# 0         10:48A                       CROSSWALK                 NaN
# 1         10:34A  FAIL TO DSPLY MUNI METER RECPT                 NaN
# 2         09:56A                       BIKE LANE                 NaN
# 3         11:57A                       BIKE LANE                 NaN
# 4         08:49A      NO PARKING-STREET CLEANING                 NaN
# 5         05:35P  FAIL TO DSPLY MUNI METER RECPT                 NaN
# 6         09:32A     NO STANDING-DAY/TIME LIMITS                 NaN
# 7         12:23P              EXPIRED MUNI METER                 NaN
# 8         08:42A    DOUBLE PARKING-MIDTOWN COMML                 NaN
# 9         01:09A  NGHT PKG ON RESID STR-COMM VEH                 NaN
#
#    Fine Amount  Penalty Amount  Interest Amount  Reduction Amount  \
# 0        115.0             0.0              0.0               0.0
# 1         65.0             0.0              0.0              37.0
# 2        115.0             0.0              0.0               0.0
# 3        115.0             0.0              0.0             115.0
# 4         45.0             0.0              0.0               0.0
# 5         35.0             0.0              0.0              35.0
# 6        115.0            10.0              0.0             125.0
# 7         35.0            10.0              0.0               0.0
# 8        115.0             0.0              0.0             115.0
# 9         65.0             0.0              0.0              65.0
#
#    Payment Amount  Amount Due  Precinct County            Issuing Agency  \
# 0           115.0         0.0      44.0     BX                   TRAFFIC
# 1            28.0         0.0      19.0     NY                   TRAFFIC
# 2           115.0         0.0      77.0      K                   TRAFFIC
# 3             0.0         0.0      14.0     NY                   TRAFFIC
# 4            45.0         0.0     104.0      Q                   TRAFFIC
# 5             0.0         0.0      66.0      K                   TRAFFIC
# 6             0.0         0.0      17.0     NY                   TRAFFIC
# 7            45.0         0.0     115.0      Q                   TRAFFIC
# 8             0.0         0.0      17.0     NY                   TRAFFIC
# 9             0.0         0.0      62.0      K  DEPARTMENT OF SANITATION
#
#                 Violation Status
# 0            HEARING HELD-GUILTY
# 1  HEARING HELD-GUILTY REDUCTION
# 2            HEARING HELD-GUILTY
# 3        HEARING HELD-NOT GUILTY
# 4                HEARING PENDING
# 5        HEARING HELD-NOT GUILTY
# 6        HEARING HELD-NOT GUILTY
# 7            HEARING HELD-GUILTY
# 8        HEARING HELD-NOT GUILTY
# 9        HEARING HELD-NOT GUILTY

# %%
print("len(status) = ", len(status))
print("license_type = ", len(license_type))
print(status)
def replaceText(name,values, datas):
    for i in range(len(values)):
        datas[name].replace(values[i],i,inplace=True)
        
for i in range(len(status)):
    data["Violation Status"].replace(status[i],i,inplace=True)
    
for i in range(len(license_type)):
    data["License Type"].replace(license_type[i],i,inplace=True)
    
for i in range(len(violation)):
    data["Violation"].replace(violation[i],i,inplace=True)

for i in range(len(county)):
    data["County"].replace(county[i],i,inplace=True)
    
for i in range(len(issu_agency)):
    data["Issuing Agency"].replace(issu_agency[i],i,inplace=True)
    
for i in range(len(state)):
    data["State"].replace(state[i],i,inplace=True)

data.drop(labels=None,axis=1, index=None, columns="Plate", inplace=True)
data.drop(labels=None,axis=1, index=None, columns="Summons Number", inplace=True)
data.drop(labels=None,axis=1, index=None, columns="Issue Date", inplace=True)
data.drop(labels=None,axis=1, index=None, columns="Violation Time", inplace=True)
data.drop(labels=None,axis=1, index=None, columns="Judgment Entry Date", inplace=True)
data.drop(labels=None,axis=1, index=None, columns="ID", inplace=True)

data.head(10)
# Out:
# len(status) =  14
# license_type =  47
# ['HEARING HELD-GUILTY' 'HEARING HELD-GUILTY REDUCTION'
#  'HEARING HELD-NOT GUILTY' 'HEARING PENDING' 'ADMIN CLAIM GRANTED'
#  'APPEAL REVERSED' 'HEARING ADJOURNMENT' 'APPEAL AFFIRMED'
#  'ADMIN CLAIM DENIED' 'ADMIN REDUCTION' 'HEARING HELD-REINSTATEMENT'
#  'APPEAL ABANDONED' 'APPEAL MODIFIED' 'HEARING WAIVED']
#    State  License Type  Violation  Fine Amount  Penalty Amount  \
# 0      0             0          0        115.0             0.0
# 1      0             1          1         65.0             0.0
# 2      0             0          2        115.0             0.0
# 3      1             0          2        115.0             0.0
# 4      0             0          3         45.0             0.0
# 5      0             0          1         35.0             0.0
# 6      0             1          4        115.0            10.0
# 7      2             2          5         35.0            10.0
# 8      3             0          6        115.0             0.0
# 9      0             1          7         65.0             0.0
#
#    Interest Amount  Reduction Amount  Payment Amount  Amount Due  Precinct  \
# 0              0.0               0.0           115.0         0.0      44.0
# 1              0.0              37.0            28.0         0.0      19.0
# 2              0.0               0.0           115.0         0.0      77.0
# 3              0.0             115.0             0.0         0.0      14.0
# 4              0.0               0.0            45.0         0.0     104.0
# 5              0.0              35.0             0.0         0.0      66.0
# 6              0.0             125.0             0.0         0.0      17.0
# 7              0.0               0.0            45.0         0.0     115.0
# 8              0.0             115.0             0.0         0.0      17.0
# 9              0.0              65.0             0.0         0.0      62.0
#
#    County  Issuing Agency  Violation Status
# 0       0               0                 0
# 1       1               0                 1
# 2       2               0                 0
# 3       1               0                 2
# 4       3               0                 3
# 5       2               0                 2
# 6       1               0                 2
# 7       3               0                 0
# 8       1               0                 2
# 9       2               1                 2

# %%
print("len(data.columns)", len(data.columns))
X = data.iloc[:, :-1]
y = data.iloc[:, -1]
le = LabelEncoder()
y = le.fit_transform(y)
X_trn, X_tst, y_trn, y_tst = train_test_split(X, y, test_size=0.3, random_state=42)
print("X_trn.shape = ",X_trn.shape)
X_trn.head(10)
# Out:
# len(data.columns) 13
# X_trn.shape =  (56000, 12)
#        State  License Type  Violation  Fine Amount  Penalty Amount  \
# 52511      0             1         38        115.0             0.0
# 36485      0             1         15         65.0            60.0
# 48982      0             1         20        115.0             0.0
# 31737      0             0          1         35.0             0.0
# 16731      0             0          1         35.0             0.0
# 3927       0             0          5         35.0             0.0
# 73223      0             1          5         65.0            10.0
# 18124      0             0          1         35.0             0.0
# 35624      0             1          2        115.0             0.0
# 10821      0             1          4        115.0             0.0
#
#        Interest Amount  Reduction Amount  Payment Amount  Amount Due  \
# 52511             0.00              0.00          115.00         0.0
# 36485            71.92              0.06          196.86         0.0
# 48982             0.00             15.00          100.00         0.0
# 31737             0.00             35.00            0.00         0.0
# 16731             0.00             35.00            0.00         0.0
# 3927              0.00             35.00            0.00         0.0
# 73223             0.00             75.00            0.00         0.0
# 18124             0.00             35.00            0.00         0.0
# 35624             0.00             10.00          105.00         0.0
# 10821             0.00             23.00           92.00         0.0
#
#        Precinct  County  Issuing Agency
# 52511       0.0       0               3
# 36485       5.0       1               0
# 48982       1.0       1               0
# 31737      46.0       0               0
# 16731     115.0       3               0
# 3927      115.0       3               0
# 73223       6.0       1               0
# 18124     112.0       3               0
# 35624      28.0       1               0
# 10821      18.0       1               0
